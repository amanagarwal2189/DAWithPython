# %%
# %matplotlib inline
import pandas as pd
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\pandas\computation\__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
titanic_df=pd.DataFrame.from_csv('data/titanic_data.csv',index_col=None, encoding='utf-8')
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
len(titanic_df)
# Out:
# 891

# %%
titanic_df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
h=titanic_df.head(4)
h
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
h['Sex']
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# Name: Sex, dtype: object

# %%
h['Age']//10*10
# Out:
# 0    20.0
# 1    30.0
# 2    20.0
# 3    30.0
# Name: Age, dtype: float64

# %%
#returns a series of true and false for this condition
h.Age >28
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# Name: Age, dtype: bool

# %%
#returns only those rows which hold true for the condition
h[h.Age >28]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C
# 3      0    113803  53.1000  C123        S

# %%
titanic_df.describe()
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# ...

# %%
t_F_15_40=titanic_df[((titanic_df.Age >= 40) | (titanic_df.Age <= 15)) &(titanic_df.Sex == 'female')]
print(t_F_15_40.Survived.sum(),len(t_F_15_40))
# Out:
# 70 97

# %%
titanic_df.sort_values('Ticket')
# Out:
#      PassengerId  Survived  Pclass  \
# 504          505         1       1
# 257          258         1       1
# 759          760         1       1
# 262          263         0       1
# 558          559         1       1
# 585          586         1       1
# 110          111         0       1
# 475          476         0       1
# 430          431         1       1
# 366          367         1       1
# 170          171         0       1
# 462          463         0       1
# 523          524         1       1
# 329          330         1       1
# 889          890         1       1
# 604          605         1       1
# 507          508         1       1
# 187          188         1       1
# 806          807         0       1
# 633          634         0       1
# 887          888         1       1
# 815          816         0       1
# 263          264         0       1
# 209          210         1       1
# 766          767         0       1
# ...

# %%
t_head = titanic_df.head(6)
t_head.Fare.sort_values()
# Out:
# 0     7.2500
# 2     7.9250
# 4     8.0500
# 5     8.4583
# 3    53.1000
# 1    71.2833
# Name: Fare, dtype: float64

# %%
t_age_notnulldata=titanic_df[titanic_df.Age.notnull()]
print(len(titanic_df),len(t_age_notnulldata))
# Out:
# 891 714

# %%
t_age_notnulldata.Age.value_counts().plot()
#yes this plot sucks. THe main reason is that even though it claims to
#be sorted, it is sorted by frequency. Hence there is a zigzag pattern
#between age. Hence, check the next cell.

# %%
t_age_notnulldata.Age.value_counts().sort_index().plot()

# %%
t_age_notnulldata.plot(x='Age', y='Survived', kind = 'scatter')
#a naive plot and unncessary one.. looks like though that no one from
#the age of 65 to 80 survived. but still..this is something we dont want

# %%
t_age_notnulldata.sort_values('Age').plot(x='Age', y='Fare')#, kind = 'scatter')

# %%
t_age_notnulldata.sort_values('Age').plot(x='Age', y='Fare', kind = 'scatter')

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
index_unsort=titanic_df.set_index(['Name'])
index_unsort.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %% [markdown]
# index is very useful in pandas. however the efficience is gained when the indexes are ordered. In this scenario, python can use Devide and Conquer algo to concentrate on the area of interest.

# %%
# %%time
index_unsort.loc['Heikkinen, Miss. Laina']
# Out:
# Wall time: 1 ms
# PassengerId                   3
# Survived                      1
# Pclass                        3
# Sex                      female
# Age                          26
# SibSp                         0
# Parch                         0
# Ticket         STON/O2. 3101282
# Fare                      7.925
# Cabin                       NaN
# Embarked                      S
# Name: Heikkinen, Miss. Laina, dtype: object

# %% [markdown]
# now let us sort the index and analyze the time of proecessing

# %%
index_sort=titanic_df.set_index(['Name']).sort_index()
index_sort.head()
# Out:
#                                        PassengerId  Survived  Pclass     Sex  \
# Name
# Abbing, Mr. Anthony                            846         0       3    male
# Abbott, Mr. Rossmore Edward                    747         0       3    male
# Abbott, Mrs. Stanton (Rosa Hunt)               280         1       3  female
# Abelson, Mr. Samuel                            309         0       2    male
# Abelson, Mrs. Samuel (Hannah Wizosky)          875         1       2  female
#
#                                         Age  SibSp  Parch     Ticket   Fare  \
# Name
# Abbing, Mr. Anthony                    42.0      0      0  C.A. 5547   7.55
# Abbott, Mr. Rossmore Edward            16.0      1      1  C.A. 2673  20.25
# Abbott, Mrs. Stanton (Rosa Hunt)       35.0      1      1  C.A. 2673  20.25
# Abelson, Mr. Samuel                    30.0      1      0  P/PP 3381  24.00
# Abelson, Mrs. Samuel (Hannah Wizosky)  28.0      1      0  P/PP 3381  24.00
#
# ...

# %%
# %%time
index_sort.loc['Heikkinen, Miss. Laina']
# Out:
# Wall time: 1 ms
# PassengerId                   3
# Survived                      1
# Pclass                        3
# Sex                      female
# Age                          26
# SibSp                         0
# Parch                         0
# Ticket         STON/O2. 3101282
# Fare                      7.925
# Cabin                       NaN
# Embarked                      S
# Name: Heikkinen, Miss. Laina, dtype: object

# %%
grptest=titanic_df[(pd.notnull(titanic_df.Age))&(titanic_df.Survived==1)]
grptest
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 52            53         1       1
# 53            54         1       2
# 56            57         1       2
# 58            59         1       2
# 61            62         1       1
# 66            67         1       2
# 68            69         1       3
# 74            75         1       3
# 78            79         1       2
# 79            80         1       3
# ...

# %%
grptest.groupby('Age').size()
# Out:
# Age
# 0.42      1
# 0.67      1
# 0.75      2
# 0.83      2
# 0.92      1
# 1.00      5
# 2.00      3
# 3.00      5
# 4.00      7
# 5.00      4
# 6.00      2
# 7.00      1
# 8.00      2
# 9.00      2
# 11.00     1
# 12.00     1
# 13.00     2
# 14.00     3
# 15.00     4
# 16.00     6
# 17.00     6
# 18.00     9
# 19.00     9
# 20.00     3
# 21.00     5
# 22.00    11
# 23.00     5
# 24.00    15
# 25.00     6
# 26.00     6
#          ..
# 32.00     9
# 32.50     1
# 33.00     6
# 34.00     6
# 35.00    11
# 36.00    11
# 37.00     1
# 38.00     5
# 39.00     5
# 40.00     6
# 41.00     2
# 42.00     6
# 43.00     1
# 44.00     3
# 45.00     5
# 47.00     1
# 48.00     6
# 49.00     4
# 50.00     5
# 51.00     2
# 52.00     3
# 53.00     1
# 54.00     3
# 55.00     1
# 56.00     2
# 58.00     3
# 60.00     2
# 62.00     2
# 63.00     2
# 80.00     1
# dtype: int64

# %%
grptest.groupby('Age').size().plot(kind='bar')

# %% [markdown]
# pretty ugle na? the x axis is all buzzed out. here's what we will do

# %%
grptest.groupby(grptest.Age//10*10).size()#plot(kind='bar')
# Out:
# Age
# 0.0     38
# 10.0    41
# 20.0    77
# 30.0    73
# 40.0    34
# 50.0    20
# 60.0     6
# 80.0     1
# dtype: int64

# %%
grptest.groupby(grptest.Age//10*10).size().plot(kind='bar')

# %% [markdown]
# # Session 4

# %% [markdown]
# Now let us see how many survivors were there in each age group based on gender

# %%
g=grptest.groupby([grptest.Age//10*10, grptest.Sex]).size()
g
# Out:
# Age   Sex
# 0.0   female    19
#       male      19
# 10.0  female    34
#       male       7
# 20.0  female    52
#       male      25
# 30.0  female    50
#       male      23
# 40.0  female    22
#       male      12
# 50.0  female    16
#       male       4
# 60.0  female     4
#       male       2
# 80.0  male       1
# dtype: int64

# %%
u=g.unstack(0)
u
# Out:
# Age     0.0   10.0  20.0  30.0  40.0  50.0  60.0  80.0
# Sex
# female  19.0  34.0  52.0  50.0  22.0  16.0   4.0   NaN
# male    19.0   7.0  25.0  23.0  12.0   4.0   2.0   1.0

# %%
u2=g.unstack(1)
u2
# Out:
# Sex   female  male
# Age
# 0.0     19.0  19.0
# 10.0    34.0   7.0
# 20.0    52.0  25.0
# 30.0    50.0  23.0
# 40.0    22.0  12.0
# 50.0    16.0   4.0
# 60.0     4.0   2.0
# 80.0     NaN   1.0

# %%
#notice female 80 is blank...USE .fillna(arg)
u2=g.unstack(1).fillna(0.0)
#and we add a new column called difference
u2['difference']=u2['female']-u2['male']
u2
# Out:
# Sex   female  male  difference
# Age
# 0.0     19.0  19.0         0.0
# 10.0    34.0   7.0        27.0
# 20.0    52.0  25.0        27.0
# 30.0    50.0  23.0        27.0
# 40.0    22.0  12.0        10.0
# 50.0    16.0   4.0        12.0
# 60.0     4.0   2.0         2.0
# 80.0     0.0   1.0        -1.0
